# %% [markdown]
# # Week 0 - 📦 Hands-on Python Packages

# %% [markdown]
# Now we have a good understanding of how the basic structure of programming works.
#
# If you are not confident, try re-visiting the earlier lessons, and doing the codes by yourself. If you are new to coding, don't worry, coding takes practice - it's a skill like learning to play a piano 🎹or guitar 🎸, or learning to ride a bicycle 🚲- you can't do it in the first round, it takes many rounds to be able to do it well.
#
#
# Recap: We already know 💪
# - how to create data structures/types (lists, dictionaries,strings,..) and store, retrieve data
# - how to use in-built python functions (print, len, append,..) for specific tasks
# - how to use conditional arguments (if/else, elif)
# - how to do iterative tasks using loops (for, while,..)
# - how to define our own function for specific tasks (def function(): ..)
#
#
# To make full use of these structures, we are now going to explore a few of the most widely used python libraries / packages.
# These libraries offer more data structures/types and functions that enables python to do a whole range of things.
#
# Some of the most widely used (essential) packages are:
# - numpy
# - pandas
# - matplotlib
# - seaborn
# - scikit learn

# %% [markdown]
# # Numpy ➕➖✖️➗
#
# You can open a new jupyter notebook and follow along with the video.
#
# ## Note:
# Since we have already installed numpy using Anaconda Prompt when we set up our virtual environment, **you don't need** to *!pip install numpy* in your jupyter notebook (as shown in the video timestamp 2:10).
# In fact the better approach is to install all your packages through Anaconda Prompt, to avoid them being installed in unwanted locations on your computer. This applies to all of the following packages.

# %% [markdown]
# <!-- Introduction to Python packages -->
# <!-- YouTube: 6. Libraries - numpy-->
#
# <iframe width="640" height="360" src="https://www.youtube.com/embed/bIS9lXH0_5E" title="Python libraries - Numpy" frameborder="0" allow="accelerometer; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# 🤔🤔🤔 Now let's check our understanding...
# and also help learn something more

# %%
from jupyterquiz import display_quiz
my_colors = {
    '--jq-multiple-choice-bg': '#2c7db0',   # question box background
}

display_quiz("quiz/lecture00_numpy.json",colors=my_colors)
# Out:
# <div id="uXzpzBRTOLmK" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #uXzpzBRTOLmK {
#    --jq-multiple-choice-bg: #2c7db0;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...

# %% [markdown]
# # Pandas 🐼📈
#
# The Pandas package uses two main data structures
# - data series
# - data frames
#
# data series is generally more useful for applications like financial data analysis, cases where a sequence of data (usually over-time) carries important information (think stock market predictions).
#
# For materials sciences we are more interested in **data frames** - which are like spreadsheets
#
# Learn more here..
#
# Note: Again, if you have already installed pandas via Anaconda prompt (recommended), you don't need to !pip install pandas in your notebook (as shown in the start of the video)
#
# [Download the dataset](data/mpg.csv) to work alongside the video tutorial

# %% [markdown]
# <!-- Introduction to Python packages -->
# <!-- YouTube: 6. Libraries - pandas-->
#
# <iframe width="640" height="360" src="https://www.youtube.com/embed/UVz-oy94Zz0" title="Python libraries - Pandas" frameborder="0" allow="accelerometer; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# 🤔🤔🤔 Test your understanding of Pandas...

# %%
display_quiz("quiz/lecture00_pandas.json",colors=my_colors)
# Out:
# <div id="KOgejZLdEmwn" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #KOgejZLdEmwn {
#    --jq-multiple-choice-bg: #2c7db0;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...

# %% [markdown]
# # Matplotlib & Seaborn 📊📉
#
# Although Pandas has some plot functions, it is very basic and limited in plotting data.
# Mat**plot**lib is a dedicated package that helps you with plotting and data visualization.
#
# Same is true for Seaborn - this is built on top of Matplotlib and provides added flexibility for plotting tasks and is particularly useful when you have to make plots for presentations or reports.
#
# These are fun packages to experiment with
#
# So let's get going...

# %% [markdown]
# <!-- Introduction to Python packages -->
# <!-- YouTube: 6. Libraries - plots-->
#
# <iframe width="640" height="360" src="https://www.youtube.com/embed/54oQcO-sOso" title="Python libraries - Pandas" frameborder="0" allow="accelerometer; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# 🤔🤔🤔 Let's check our understanding...
#
# if you'd like you can try these codes out in your notebook before you click the answer.

# %%
display_quiz("quiz/lecture00_plots.json",colors=my_colors)
# Out:
# <div id="rGQgiwjWORkv" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #rGQgiwjWORkv {
#    --jq-multiple-choice-bg: #2c7db0;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...

# %% [markdown]
# # Scikit learn (also known as Sklearn) 📝
#
# This package has all the tools you need to work with (Classical) Machine Learning.
#
# These include:
# - machine learning models
# - functions to handle data processing (splitting, scaling,...)
# - tools to optimize models (hyper-parameter tuning, cross-validation,...)
# - metrics to evaluate model performance
# - ...
#
#   And we will introduce these as we progress through the course.
#   But there's nothing new to learn here. Once you've understood what we've covered up to now, and practiced them multiple times you can easily apply the same ideas to any other package in python.
#
#   Note: Scikit learn is designed for classical machine learning - which we will cover in this course.
#   Deep learning (neural networks) require other packages (pytorch, tensorflow,...) which we will not cover in this course.
#
#   Once you are comfortable handling Python at a basic level, we can move on to Machine Learning.
