# %% [markdown]
# Import numpy, pandas and matplotlib.pyplot
# *******************

# %% [markdown]
# Read the dataset and store it as data
# ************

# %% [markdown]
# Check the first few lines of the dataset to see how the dataframe looks like
# *************

# %% [markdown]
# Check the length of the dataset (number of rows)
# **********

# %% [markdown]
# Clean data - If there are any NAN data, drop them by rows and save it as a separate file.
# ******

# %% [markdown]
# Re-check the length of the data to see if any rows have been dropped
# *********

# %% [markdown]
# There are some unnecessary columns of data in the dataset, to keep things simple, it is better to drop them.
# Keep the 'formula, and 'formation_energy_peratom' columns and drop the rest, and save it as a separate file
#
# Check to see if the new dataset looks acceptable.
# ****************

# %% [markdown]
# We need to use the CBFV package to featurize the data. The CBFV package requires the dataset columns X and y to be named as 'formula' and 'target'.
# Rename as above and save as a separate variable.
#
# Also, check if they have were renamed as required.
# ***********

# %% [markdown]
# Now check the shape of X, and y data to ensure they are in (number, 1) format where number refers to the number of columns
# **********

# %% [markdown]
# Import the composition module from CBFV, and the train_test_split from sklearn
# **********

# %% [markdown]
# Generate feature vectors from the prepared data, use the 'oliynyk' format for feature generation
#
# Later: Once you complete the model, you can try out the other formats such as magpie and jarvis and see which works best
# ***********

# %% [markdown]
# Check the first few rows of the generated feature vectors dataset
# ********

# %% [markdown]
# split the data into train and test sets, with a 0.8 / 0.2 ratio
# **********

# %% [markdown]
# Check the length of either split to ensure the size of the sample set is correct
# *******

# %% [markdown]
# import the StandardScaler and normalize from sklearn
# **********
#
# In a StandardScaler object:
#
# During the fit process, the statistics of the input data (mean and standard deviation) are computed.
# Then, during the transform process, the mean and standard deviation values calculated above are used to scale the data to having zero-mean and unit variance.
# Therefore, for the first time usage of the scaler, we call the .fit_transform() method to fit the scaler to the input data, and then to transform the same data. For subsequent uses, since we have already computed the statistics, we only call the .transform() method to scale data.
#
# Note: you should only .fit() the scaler using the training dataset statistics, and then use these same statistics from the training dataset to .transform() the other datasets (validation and train).

# %% [markdown]
# Use the StandardScaler to fit to the X train data,
# Then use the scaler to transform the X test data (do not fit to X data)
# ********

# %% [markdown]
# Normalize both train and test data
# ***********

# %% [markdown]
# Import Linear Regression model from sklearn
# **********

# %% [markdown]
# Create an instance of a linear Regression model
# **********

# %% [markdown]
# Fit the model to the train data
# *******

# %% [markdown]
# Check the r2 score of the training set
# *********

# %% [markdown]
# Also test the r2 score of the test set
# *******
