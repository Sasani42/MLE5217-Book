# %%
#Formation energy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("formation_data.csv")

# %%
data.head()
# Out:
#            jid  spg_number spg_symbol   formula  formation_energy_peratom  \
# 0  JVASP-90856         129     P4/nmm  TiCuSiAs                  -0.42762
# 1  JVASP-86097         221      Pm-3m      DyB6                  -0.41596
# 2  JVASP-64906         119      I-4m2   Be2OsRu                   0.04847
# 3  JVASP-98225          14     P2_1/c       KBi                  -0.44140
# 4     JVASP-10         164      P-3m1      VSe2                  -0.71026
#
#         func  optb88vdw_bandgap
# 0  OptB88vdW              0.000
# 1  OptB88vdW              0.000
# 2  OptB88vdW              0.000
# 3  OptB88vdW              0.472
# 4  OptB88vdW              0.000

# %%
len(data)
# Out:
# 55716

# %%
data1=data.dropna(axis=0,how='any')

# %%
len(data1)
# Out:
# 55714

# %%
data2=data1.drop(['optb88vdw_bandgap','func','spg_symbol','spg_number','jid'],axis=1)
data2.head()
# Out:
#     formula  formation_energy_peratom
# 0  TiCuSiAs                  -0.42762
# 1      DyB6                  -0.41596
# 2   Be2OsRu                   0.04847
# 3       KBi                  -0.44140
# 4      VSe2                  -0.71026

# %%
data3=data2.rename(columns={'formation_energy_peratom':'target'})
data3.head()
# Out:
#     formula   target
# 0  TiCuSiAs -0.42762
# 1      DyB6 -0.41596
# 2   Be2OsRu  0.04847
# 3       KBi -0.44140
# 4      VSe2 -0.71026

# %%
print(f'shape of X:{formula.shape}')
print(f'shape of y:{target.shape}')
# Out:
# shape of X:(55721, 1)
# shape of y:(55721, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
from CBFV import composition

# %%
X,y,formulae,skipped=composition.generate_features(data3,elem_prop='oliynyk')
# Out:
# Processing Input Data: 100%|██████████| 55714/55714 [00:01<00:00, 28776.58it/s]
# 	Featurizing Compositions...
# Assigning Features...: 100%|██████████| 55714/55714 [00:03<00:00, 17528.50it/s]
# NOTE: Your data contains formula with exotic elements. These were skipped.
# 	Creating Pandas Objects...

# %%
X.head()

#X=data3[['formula']]
#y=data3[['target']]
# Out:
#    avg_Atomic_Number  avg_Atomic_Weight  avg_Period  avg_group  avg_families  \
# 0          24.500000          53.608272    3.750000  11.000000      5.000000
# 1          13.714286          32.480857    2.571429  11.571429      5.571429
# 2          32.000000          77.331090    3.750000   5.000000      3.000000
# 3          51.000000         124.039335    5.000000   8.000000      3.000000
# 4          30.333333          69.620500    4.000000  12.333333      6.000000
#
#    avg_Metal  avg_Nonmetal  avg_Metalliod  avg_Mendeleev_Number  \
# 0   0.500000      0.250000       0.250000             67.250000
# 1   0.142857      0.000000       0.857143             66.142857
# 2   1.000000      0.000000       0.000000             61.750000
# 3   1.000000      0.000000       0.000000             44.500000
# 4   0.333333      0.666667       0.000000             74.666667
#
#    avg_l_quantum_number  ...  mode_polarizability(A^3)  \
# 0              1.500000  ...                       4.3
# ...

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2)

# %%
len(X_test)
# Out:
# 11143

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize

# %%
scaler=StandardScaler()

X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_data=normalize(X_train_scaled)
X_test_data=normalize(X_test_scaled)

# %%
# Fit a linear regression model
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
result=model.fit(X_train,y_train)

# %%
r2=model.score(X_train,y_train)
print(r2)
# Out:
# 0.8400530210051068

# %%
r2_test=model.score(X_test,y_test)
print(r2_test)
# Out:
# 0.8369350376253455
